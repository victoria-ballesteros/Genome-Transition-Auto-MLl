# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from autogluon.tabular import TabularPredictor
import matplotlib.pyplot as plt
import os

# %%
# remove models folder if it exists
import shutil
shutil.rmtree("../models", ignore_errors=True)

# %%
def prepare_data(true_data, counter_files, max_index):
    combined_data = {}
    # Define the column names to keep.
    cols = [f"B{i}" for i in range(1, max_index + 1)]

    # Process the true data: retain only the B columns and add the true label.
    true_data['label'] = "true"
    true_data = true_data[cols + ["label"]]

    for key, df_counter in counter_files.items():
        # Retain only the B columns and add the false label.
        df_counter['label'] = "false"
        df_counter = df_counter[cols + ["label"]]
        # Combine the true data with this counter example.
        combined = pd.concat([true_data, df_counter], ignore_index=True)
        combined_data[key] = combined

    return combined_data

# %%
presets = ['good_quality', 'optimize_for_deployment']

def generateModels(combined_data, prefix, max_index, time_limit=180):
    results = {}
    # Define the feature columns
    feature_cols = [f"B{i}" for i in range(1, max_index + 1)]

    for key, df in combined_data.items():
        # Split data into features and label.
        X = df[feature_cols]
        y = df["label"]

        # Train-test split: 70% train, 30% test.
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
        train_data = pd.concat([X_train, y_train], axis=1)
        test_data = pd.concat([X_test, y_test], axis=1)

        # Define an output folder for saving models for this dataset variant.
        output_folder = f"../models/{prefix}/{key}"
        os.makedirs(output_folder, exist_ok=True)

        # Train the model using AutoGluon.
        predictor = TabularPredictor(label="label", path=output_folder, eval_metric='f1').fit(train_data, presets=presets, time_limit=time_limit)

        # Evaluate the model on the test data.
        leaderboard = predictor.leaderboard(test_data, silent=True)
        results[key] = leaderboard

        print(f"Results for {key}:")
        print(leaderboard)

    # Create results folder and save leaderboards.
    results_folder = f"../models/{prefix}/results"
    os.makedirs(results_folder, exist_ok=True)
    for key, result in results.items():
        result.to_csv(os.path.join(results_folder, f"{key}_leaderboard.csv"), index=False)

# %%
true_file = "../data/ei/data_ei.csv"
ei_true_data = pd.read_csv(true_file)

# List of counter example files for the EI zone
counter_files = {
    "combined": pd.concat(
        [
            pd.read_csv("../data/ei/data_ei_random.csv"),
            pd.read_csv("../data/ei/data_ez_counter_example.csv"),
            pd.read_csv("../data/ei/data_ie_counter_example.csv"),
            pd.read_csv("../data/ei/data_ze_counter_example.csv"),
            pd.read_csv("../data/ei/data_ie_true_counter_example.csv"),
            pd.read_csv("../data/ei/data_test_false.csv"),
         ]
    )
}

# For EI zone, our CSV files have columns B1 to B12.
combined_data = prepare_data(ei_true_data, counter_files, max_index=12)

# Dictionary to store the combined DataFrames and later model results
generateModels(combined_data, 'ei', 12, time_limit=21600)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="../models/ei/combined"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.2
# Python Version:     3.9.13
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          16
# Memory Avail:       6.45 GB / 15.35 GB (42.0%)
# Disk Space Avail:   47.75 GB / 100.00 GB (47.7%)
# ===================================================
# Presets specified: ['good_quality', 'optimize_for_deployment']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Note: `save_bag_folds=False`! This will greatly reduce peak disk usage during fit (by ~8x), but runs the risk of an out-of-memory error during model refit if memory is small relative to the data size.
# 	You can avoid this risk by setting `save_bag_folds=True`.
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 5400s of the 21600s of remaining time (25%).
# 2025-03-28 11:30:43,338	INFO util.py:154 -- Missing packages: ['ipywidgets']. Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-03-28 11:30:48,446	INFO worker.py:1810 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# 		Context path: "D:\projects\python\Genome-Transition-Auto-MLl\models\ei\combined\ds_sub_fit\sub_fit_ho"
# (_dystack pid=14208) Running DyStack sub-fit ...
# (_dystack pid=14208) Beginning AutoGluon training ... Time limit = 5390s
# (_dystack pid=14208) AutoGluon will save models to "D:\projects\python\Genome-Transition-Auto-MLl\models\ei\combined\ds_sub_fit\sub_fit_ho"
# (_dystack pid=14208) Train Data Rows:    85576
# (_dystack pid=14208) Train Data Columns: 12
# (_dystack pid=14208) Label Column:       label
# (_dystack pid=14208) Problem Type:       binary
# (_dystack pid=14208) Preprocessing data ...
# (_dystack pid=14208) Selected class <--> label mapping:  class 1 = true, class 0 = false
# (_dystack pid=14208) 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (true) vs negative (false) class.
# (_dystack pid=14208) 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# (_dystack pid=14208) Using Feature Generators to preprocess the data ...
# (_dystack pid=14208) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=14208) 	Available Memory:                    5990.04 MB
# (_dystack pid=14208) 	Train Data (Original)  Memory Usage: 56.80 MB (0.9% of available memory)
# (_dystack pid=14208) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=14208) 	Stage 1 Generators:
# (_dystack pid=14208) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=14208) 	Stage 2 Generators:
# (_dystack pid=14208) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=14208) 	Stage 3 Generators:
# (_dystack pid=14208) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=14208) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=14208) 	Stage 4 Generators:
# (_dystack pid=14208) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=14208) 	Stage 5 Generators:
# (_dystack pid=14208) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=14208) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=14208) 		('object', []) : 12 | ['B1', 'B2', 'B3', 'B4', 'B5', ...]
# (_dystack pid=14208) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=14208) 		('category', []) : 12 | ['B1', 'B2', 'B3', 'B4', 'B5', ...]
# (_dystack pid=14208) 	0.4s = Fit runtime
# (_dystack pid=14208) 	12 features in original data used to generate 12 features in processed data.
# (_dystack pid=14208) 	Train Data (Processed) Memory Usage: 0.99 MB (0.0% of available memory)
# (_dystack pid=14208) Data preprocessing and feature engineering runtime = 0.4s ...
# (_dystack pid=14208) AutoGluon will gauge predictive performance using evaluation metric: 'f1'
# (_dystack pid=14208) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=14208) User-specified model hyperparameters to be fit:
# (_dystack pid=14208) {
# (_dystack pid=14208) 	'NN_TORCH': [{}],
# (_dystack pid=14208) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# (_dystack pid=14208) 	'CAT': [{}],
# (_dystack pid=14208) 	'XGB': [{}],
# (_dystack pid=14208) 	'FASTAI': [{}],
# (_dystack pid=14208) 	'RF': [{'criterion': 'gini', 'max_depth': 15, 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'max_depth': 15, 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'max_depth': 15, 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=14208) 	'XT': [{'criterion': 'gini', 'max_depth': 15, 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'max_depth': 15, 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'max_depth': 15, 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=14208) }
# (_dystack pid=14208) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=14208) Fitting 11 L1 models, fit_strategy="sequential" ...
# (_dystack pid=14208) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 3592.32s of the 5389.83s of remaining time.
# (_dystack pid=14208) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.23%)
# (_ray_fit pid=22400) [1000]	valid_set's binary_logloss: 0.063705	valid_set's f1: 0.957524
# (_ray_fit pid=22400) [2000]	valid_set's binary_logloss: 0.0596066	valid_set's f1: 0.962963 [repeated 8x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (_ray_fit pid=22400) [3000]	valid_set's binary_logloss: 0.058624	valid_set's f1: 0.963412 [repeated 8x across cluster]
# (_ray_fit pid=22400) [4000]	valid_set's binary_logloss: 0.0589464	valid_set's f1: 0.965462 [repeated 8x across cluster]
# (_ray_fit pid=22400) [5000]	valid_set's binary_logloss: 0.0598116	valid_set's f1: 0.965489 [repeated 7x across cluster]
# (_ray_fit pid=22400) [6000]	valid_set's binary_logloss: 0.0608523	valid_set's f1: 0.966505 [repeated 7x across cluster]
# (_ray_fit pid=22400) [7000]	valid_set's binary_logloss: 0.0619875	valid_set's f1: 0.966714 [repeated 6x across cluster]
# (_ray_fit pid=22400) [8000]	valid_set's binary_logloss: 0.0635435	valid_set's f1: 0.966895 [repeated 6x across cluster]
# (_ray_fit pid=22400) [9000]	valid_set's binary_logloss: 0.06511	valid_set's f1: 0.967286 [repeated 4x across cluster]
# (_ray_fit pid=22400) [10000]	valid_set's binary_logloss: 0.0663259	valid_set's f1: 0.966882 [repeated 3x across cluster]
# (_dystack pid=14208) 	0.9675	 = Validation score   (f1)
# (_dystack pid=14208) 	132.8s	 = Training   runtime
# (_dystack pid=14208) 	51.79s	 = Validation runtime
# (_dystack pid=14208) Fitting model: LightGBM_BAG_L1 ... Training model for up to 3442.75s of the 5240.25s of remaining time.
# (_dystack pid=14208) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.23%)
# (_ray_fit pid=8328) [1000]	valid_set's binary_logloss: 0.0611877	valid_set's f1: 0.960582
# (_ray_fit pid=24548) [1000]	valid_set's binary_logloss: 0.0657267	valid_set's f1: 0.955569
# (_ray_fit pid=8328) [2000]	valid_set's binary_logloss: 0.0575243	valid_set's f1: 0.965253 [repeated 7x across cluster]
# (_ray_fit pid=8328) [3000]	valid_set's binary_logloss: 0.0570503	valid_set's f1: 0.96631 [repeated 7x across cluster]
# (_ray_fit pid=8328) [4000]	valid_set's binary_logloss: 0.0580491	valid_set's f1: 0.96713 [repeated 7x across cluster]
# (_ray_fit pid=8328) [5000]	valid_set's binary_logloss: 0.059545	valid_set's f1: 0.966895 [repeated 7x across cluster]
# (_ray_fit pid=20476) [6000]	valid_set's binary_logloss: 0.0584109	valid_set's f1: 0.966465 [repeated 7x across cluster]
# (_ray_fit pid=24256) [7000]	valid_set's binary_logloss: 0.061186	valid_set's f1: 0.969855 [repeated 6x across cluster]
# (_ray_fit pid=24256) [8000]	valid_set's binary_logloss: 0.0626911	valid_set's f1: 0.970636 [repeated 4x across cluster]
# (_ray_fit pid=24256) [9000]	valid_set's binary_logloss: 0.0641141	valid_set's f1: 0.970233 [repeated 3x across cluster]
# (_ray_fit pid=24256) [10000]	valid_set's binary_logloss: 0.0655922	valid_set's f1: 0.970417
# (_dystack pid=14208) 	0.9675	 = Validation score   (f1)
# (_dystack pid=14208) 	135.31s	 = Training   runtime
# (_dystack pid=14208) 	45.56s	 = Validation runtime
# (_dystack pid=14208) Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 3294.71s of the 5092.22s of remaining time.
# (_dystack pid=14208) 	0.9627	 = Validation score   (f1)
# (_dystack pid=14208) 	2.53s	 = Training   runtime
# (_dystack pid=14208) 	1.67s	 = Validation runtime
# (_dystack pid=14208) Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 3290.31s of the 5087.81s of remaining time.
# (_dystack pid=14208) 	0.9614	 = Validation score   (f1)
# (_dystack pid=14208) 	2.03s	 = Training   runtime
# (_dystack pid=14208) 	1.68s	 = Validation runtime
# (_dystack pid=14208) Fitting model: CatBoost_BAG_L1 ... Training model for up to 3286.40s of the 5083.90s of remaining time.
# (_dystack pid=14208) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.27%)
# (_ray_fit pid=22184) 	Ran out of time, early stopping on iteration 8022.
# (_dystack pid=14208) 	0.9601	 = Validation score   (f1)
# (_dystack pid=14208) 	2629.87s	 = Training   runtime
# (_dystack pid=14208) 	0.62s	 = Validation runtime
# (_dystack pid=14208) Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 653.29s of the 2450.80s of remaining time.
# (_dystack pid=14208) 	0.9584	 = Validation score   (f1)
# (_dystack pid=14208) 	2.18s	 = Training   runtime
# (_dystack pid=14208) 	1.73s	 = Validation runtime
# (_dystack pid=14208) Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 649.08s of the 2446.59s of remaining time.
# (_ray_fit pid=24292) 	Ran out of time, early stopping on iteration 8191. [repeated 7x across cluster]
# (_dystack pid=14208) 	0.9569	 = Validation score   (f1)
# (_dystack pid=14208) 	1.72s	 = Training   runtime
# (_dystack pid=14208) 	1.7s	 = Validation runtime
# (_dystack pid=14208) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 645.48s of the 2442.98s of remaining time.
# (_dystack pid=14208) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.27%)
# (_dystack pid=14208) 	0.9581	 = Validation score   (f1)
# (_dystack pid=14208) 	124.3s	 = Training   runtime
# (_dystack pid=14208) 	1.45s	 = Validation runtime
# (_dystack pid=14208) Fitting model: XGBoost_BAG_L1 ... Training model for up to 511.13s of the 2308.64s of remaining time.
# (_dystack pid=14208) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.30%)
# (_dystack pid=14208) 	0.9679	 = Validation score   (f1)
# (_dystack pid=14208) 	110.17s	 = Training   runtime
# (_dystack pid=14208) 	3.01s	 = Validation runtime
# (_dystack pid=14208) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 397.34s of the 2194.84s of remaining time.
# (_dystack pid=14208) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.16%)
# (_ray_fit pid=23048) 	Ran out of time, stopping training early. (Stopping on epoch 77)
# (_dystack pid=14208) 	0.9673	 = Validation score   (f1)
# (_dystack pid=14208) 	319.95s	 = Training   runtime
# (_dystack pid=14208) 	0.5s	 = Validation runtime
# (_dystack pid=14208) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 74.17s of the 1871.68s of remaining time.
# (_dystack pid=14208) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.41%)
# (_ray_fit pid=16784) [1000]	valid_set's binary_logloss: 0.0566452	valid_set's f1: 0.962888
# (_ray_fit pid=16784) [2000]	valid_set's binary_logloss: 0.0558062	valid_set's f1: 0.965337 [repeated 8x across cluster]
# (_ray_fit pid=16784) [3000]	valid_set's binary_logloss: 0.0568761	valid_set's f1: 0.967104 [repeated 7x across cluster]
# (_ray_fit pid=16784) 	Ran out of time, early stopping on iteration 3371. Best iteration is:
# (_ray_fit pid=16784) 	[3366]	valid_set's binary_logloss: 0.0576004	valid_set's f1: 0.968094
# (_ray_fit pid=23988) 	Ran out of time, stopping training early. (Stopping on epoch 78) [repeated 7x across cluster]
# (_dystack pid=14208) 	0.9685	 = Validation score   (f1)
# (_dystack pid=14208) 	61.51s	 = Training   runtime
# (_dystack pid=14208) 	107.11s	 = Validation runtime
# (_ray_fit pid=13232) 	Ran out of time, early stopping on iteration 3303. Best iteration is: [repeated 6x across cluster]
# (_ray_fit pid=13232) 	[2885]	valid_set's binary_logloss: 0.0579046	valid_set's f1: 0.965852 [repeated 6x across cluster]
# (_dystack pid=14208) Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 1790.53s of remaining time.
# (_dystack pid=14208) 	Ensemble Weights: {'NeuralNetTorch_BAG_L1': 0.3, 'LightGBMXT_BAG_L1': 0.15, 'LightGBM_BAG_L1': 0.15, 'RandomForestGini_BAG_L1': 0.15, 'RandomForestEntr_BAG_L1': 0.1, 'ExtraTreesGini_BAG_L1': 0.1, 'LightGBMLarge_BAG_L1': 0.05}
# (_dystack pid=14208) 	0.9702	 = Validation score   (f1)
# (_dystack pid=14208) 	5.04s	 = Training   runtime
# (_dystack pid=14208) 	0.02s	 = Validation runtime
# (_dystack pid=14208) Fitting 11 L2 models, fit_strategy="sequential" ...
# (_dystack pid=14208) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 1785.43s of the 1785.42s of remaining time.
# (_dystack pid=14208) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.58%)
# (_dystack pid=14208) 	0.9704	 = Validation score   (f1)
# (_dystack pid=14208) 	7.73s	 = Training   runtime
# (_dystack pid=14208) 	0.59s	 = Validation runtime
# (_dystack pid=14208) Fitting model: LightGBM_BAG_L2 ... Training model for up to 1774.40s of the 1774.39s of remaining time.
# (_dystack pid=14208) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.58%)
# (_dystack pid=14208) 	0.9717	 = Validation score   (f1)
# (_dystack pid=14208) 	4.11s	 = Training   runtime
# (_dystack pid=14208) 	0.17s	 = Validation runtime
# (_dystack pid=14208) Fitting model: RandomForestGini_BAG_L2 ... Training model for up to 1767.09s of the 1767.08s of remaining time.
# (_dystack pid=14208) 	0.9725	 = Validation score   (f1)
# (_dystack pid=14208) 	5.66s	 = Training   runtime
# (_dystack pid=14208) 	1.69s	 = Validation runtime
# (_dystack pid=14208) Fitting model: RandomForestEntr_BAG_L2 ... Training model for up to 1759.55s of the 1759.54s of remaining time.
# (_dystack pid=14208) 	0.9721	 = Validation score   (f1)
# (_dystack pid=14208) 	5.24s	 = Training   runtime
# (_dystack pid=14208) 	1.64s	 = Validation runtime
# (_dystack pid=14208) Fitting model: CatBoost_BAG_L2 ... Training model for up to 1752.48s of the 1752.48s of remaining time.
# (_dystack pid=14208) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.64%)
# (_dystack pid=14208) 	0.9718	 = Validation score   (f1)
# (_dystack pid=14208) 	352.46s	 = Training   runtime
# (_dystack pid=14208) 	0.14s	 = Validation runtime
# (_dystack pid=14208) Fitting model: ExtraTreesGini_BAG_L2 ... Training model for up to 1396.89s of the 1396.88s of remaining time.
# (_dystack pid=14208) 	0.9726	 = Validation score   (f1)
# (_dystack pid=14208) 	2.71s	 = Training   runtime
# (_dystack pid=14208) 	1.73s	 = Validation runtime
# (_dystack pid=14208) Fitting model: ExtraTreesEntr_BAG_L2 ... Training model for up to 1392.27s of the 1392.26s of remaining time.
# (_dystack pid=14208) 	0.972	 = Validation score   (f1)
# (_dystack pid=14208) 	2.3s	 = Training   runtime
# (_dystack pid=14208) 	1.71s	 = Validation runtime
# (_dystack pid=14208) Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1388.08s of the 1388.07s of remaining time.
# (_dystack pid=14208) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.86%)
# (_dystack pid=14208) 	0.9725	 = Validation score   (f1)
# (_dystack pid=14208) 	133.67s	 = Training   runtime
# (_dystack pid=14208) 	2.06s	 = Validation runtime
# (_dystack pid=14208) Fitting model: XGBoost_BAG_L2 ... Training model for up to 1251.13s of the 1251.12s of remaining time.
# (_dystack pid=14208) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.86%)
# (_dystack pid=14208) 	0.9716	 = Validation score   (f1)
# (_dystack pid=14208) 	10.47s	 = Training   runtime
# (_dystack pid=14208) 	0.35s	 = Validation runtime
# (_dystack pid=14208) Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 1237.36s of the 1237.36s of remaining time.
# (_dystack pid=14208) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.50%)
# (_dystack pid=14208) 	0.9692	 = Validation score   (f1)
# (_dystack pid=14208) 	326.83s	 = Training   runtime
# (_dystack pid=14208) 	0.71s	 = Validation runtime
# (_dystack pid=14208) Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 907.24s of the 907.23s of remaining time.
# (_dystack pid=14208) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=2, gpus=0, memory=0.80%)
# (_dystack pid=14208) 	0.9727	 = Validation score   (f1)
# (_dystack pid=14208) 	10.82s	 = Training   runtime
# (_dystack pid=14208) 	0.62s	 = Validation runtime
# (_dystack pid=14208) Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.00s of the 892.94s of remaining time.
# (_dystack pid=14208) 	Ensemble Weights: {'LightGBMLarge_BAG_L2': 0.75, 'ExtraTreesGini_BAG_L2': 0.167, 'RandomForestGini_BAG_L1': 0.083}
# (_dystack pid=14208) 	0.9727	 = Validation score   (f1)
# (_dystack pid=14208) 	9.62s	 = Training   runtime
# (_dystack pid=14208) 	0.02s	 = Validation runtime
# (_dystack pid=14208) AutoGluon training complete, total runtime = 4506.94s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 50.5 rows/s (10697 batch size)
# (_dystack pid=14208) Automatically performing refit_full as a post-fit operation (due to `.fit(..., refit_full=True)`
# (_dystack pid=14208) Refitting models via `predictor.refit_full` using all of the data (combined train and validation)...
# (_dystack pid=14208) 	Models trained in this way will have the suffix "_FULL" and have NaN validation score.
# (_dystack pid=14208) 	This process is not bound by time_limit, but should take less time than the original `predictor.fit` call.
# (_dystack pid=14208) 	To learn more, refer to the `.refit_full` method docstring which explains how "_FULL" models differ from normal models.
# (_dystack pid=14208) Fitting 1 L1 models, fit_strategy="sequential" ...
# (_dystack pid=14208) Fitting model: LightGBMXT_BAG_L1_FULL ...
# (_dystack pid=14208) 	8.96s	 = Training   runtime
# (_dystack pid=14208) Fitting 1 L1 models, fit_strategy="sequential" ...
# (_dystack pid=14208) Fitting model: LightGBM_BAG_L1_FULL ...
# (_dystack pid=14208) 	8.61s	 = Training   runtime
# (_dystack pid=14208) Fitting model: RandomForestGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# (_dystack pid=14208) 	2.53s	 = Training   runtime
# (_dystack pid=14208) 	1.67s	 = Validation runtime
# (_dystack pid=14208) Fitting model: RandomForestEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# (_dystack pid=14208) 	2.03s	 = Training   runtime
# (_dystack pid=14208) 	1.68s	 = Validation runtime
# (_dystack pid=14208) Fitting 1 L1 models, fit_strategy="sequential" ...
# (_dystack pid=14208) Fitting model: CatBoost_BAG_L1_FULL ...
# (_dystack pid=14208) 	601.96s	 = Training   runtime
# (_dystack pid=14208) Fitting model: ExtraTreesGini_BAG_L1_FULL | Skipping fit via cloning parent ...
# (_dystack pid=14208) 	2.18s	 = Training   runtime
# (_dystack pid=14208) 	1.73s	 = Validation runtime
# (_dystack pid=14208) Fitting model: ExtraTreesEntr_BAG_L1_FULL | Skipping fit via cloning parent ...
# (_dystack pid=14208) 	1.72s	 = Training   runtime
# (_dystack pid=14208) 	1.7s	 = Validation runtime
# (_dystack pid=14208) Fitting 1 L1 models, fit_strategy="sequential" ...
# (_dystack pid=14208) Fitting model: NeuralNetFastAI_BAG_L1_FULL ...
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) No improvement since epoch 0: early stopping
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) 	49.28s	 = Training   runtime
# (_dystack pid=14208) Fitting 1 L1 models, fit_strategy="sequential" ...
# (_dystack pid=14208) Fitting model: XGBoost_BAG_L1_FULL ...
# (_dystack pid=14208) 	3.65s	 = Training   runtime
# (_dystack pid=14208) Fitting 1 L1 models, fit_strategy="sequential" ...
# (_dystack pid=14208) Fitting model: NeuralNetTorch_BAG_L1_FULL ...
# (_dystack pid=14208) 	161.67s	 = Training   runtime
# (_dystack pid=14208) Fitting 1 L1 models, fit_strategy="sequential" ...
# (_dystack pid=14208) Fitting model: LightGBMLarge_BAG_L1_FULL ...
# (_dystack pid=14208) 	8.96s	 = Training   runtime
# (_dystack pid=14208) Fitting model: WeightedEnsemble_L2_FULL | Skipping fit via cloning parent ...
# (_dystack pid=14208) 	Ensemble Weights: {'NeuralNetTorch_BAG_L1': 0.3, 'LightGBMXT_BAG_L1': 0.15, 'LightGBM_BAG_L1': 0.15, 'RandomForestGini_BAG_L1': 0.15, 'RandomForestEntr_BAG_L1': 0.1, 'ExtraTreesGini_BAG_L1': 0.1, 'LightGBMLarge_BAG_L1': 0.05}
# (_dystack pid=14208) 	5.04s	 = Training   runtime
# (_dystack pid=14208) Fitting 1 L2 models, fit_strategy="sequential" ...
# (_dystack pid=14208) Fitting model: LightGBMXT_BAG_L2_FULL ...
# (_dystack pid=14208) 	0.74s	 = Training   runtime
# (_dystack pid=14208) Fitting 1 L2 models, fit_strategy="sequential" ...
# (_dystack pid=14208) Fitting model: LightGBM_BAG_L2_FULL ...
# (_dystack pid=14208) 	0.44s	 = Training   runtime
# (_dystack pid=14208) Fitting model: RandomForestGini_BAG_L2_FULL | Skipping fit via cloning parent ...
# (_dystack pid=14208) 	5.66s	 = Training   runtime
# (_dystack pid=14208) 	1.69s	 = Validation runtime
# (_dystack pid=14208) Fitting model: RandomForestEntr_BAG_L2_FULL | Skipping fit via cloning parent ...
# (_dystack pid=14208) 	5.24s	 = Training   runtime
# (_dystack pid=14208) 	1.64s	 = Validation runtime
# (_dystack pid=14208) Fitting 1 L2 models, fit_strategy="sequential" ...
# (_dystack pid=14208) Fitting model: CatBoost_BAG_L2_FULL ...
# (_dystack pid=14208) 	68.34s	 = Training   runtime
# (_dystack pid=14208) Fitting model: ExtraTreesGini_BAG_L2_FULL | Skipping fit via cloning parent ...
# (_dystack pid=14208) 	2.71s	 = Training   runtime
# (_dystack pid=14208) 	1.73s	 = Validation runtime
# (_dystack pid=14208) Fitting model: ExtraTreesEntr_BAG_L2_FULL | Skipping fit via cloning parent ...
# (_dystack pid=14208) 	2.3s	 = Training   runtime
# (_dystack pid=14208) 	1.71s	 = Validation runtime
# (_dystack pid=14208) Fitting 1 L2 models, fit_strategy="sequential" ...
# (_dystack pid=14208) Fitting model: NeuralNetFastAI_BAG_L2_FULL ...
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) No improvement since epoch 0: early stopping
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
# (_dystack pid=14208)   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# (_dystack pid=14208) 	54.0s	 = Training   runtime
# (_dystack pid=14208) Fitting 1 L2 models, fit_strategy="sequential" ...
# (_dystack pid=14208) Fitting model: XGBoost_BAG_L2_FULL ...
# (_dystack pid=14208) 	0.62s	 = Training   runtime
# (_dystack pid=14208) Fitting 1 L2 models, fit_strategy="sequential" ...
# (_dystack pid=14208) Fitting model: NeuralNetTorch_BAG_L2_FULL ...
# (_dystack pid=14208) 	57.61s	 = Training   runtime
# (_dystack pid=14208) Fitting 1 L2 models, fit_strategy="sequential" ...
# (_dystack pid=14208) Fitting model: LightGBMLarge_BAG_L2_FULL ...
# (_dystack pid=14208) 	1.02s	 = Training   runtime
# (_dystack pid=14208) Fitting model: WeightedEnsemble_L3_FULL | Skipping fit via cloning parent ...
# (_dystack pid=14208) 	Ensemble Weights: {'LightGBMLarge_BAG_L2': 0.75, 'ExtraTreesGini_BAG_L2': 0.167, 'RandomForestGini_BAG_L1': 0.083}
# (_dystack pid=14208) 	9.62s	 = Training   runtime
# (_dystack pid=14208) Updated best model to "WeightedEnsemble_L3_FULL" (Previously "WeightedEnsemble_L3"). AutoGluon will default to using "WeightedEnsemble_L3_FULL" for predict() and predict_proba().
# (_dystack pid=14208) Refit complete, total runtime = 1030.71s ... Best model: "WeightedEnsemble_L3_FULL"
# (_dystack pid=14208) Enabling decision threshold calibration (calibrate_decision_threshold='auto', metric is valid, problem_type is 'binary')
# (_dystack pid=14208) Calibrating decision threshold to optimize metric f1 | Checking 51 thresholds...
# (_dystack pid=14208) Calibrating decision threshold via fine-grained search | Checking 38 thresholds...
# (_dystack pid=14208) 	Base Threshold: 0.500	| val: 0.9727
# (_dystack pid=14208) 	Best Threshold: 0.502	| val: 0.9727
# (_dystack pid=14208) Updating predictor.decision_threshold from 0.5 -> 0.502
# (_dystack pid=14208) 	This will impact how prediction probabilities are converted to predictions in binary classification.
# (_dystack pid=14208) 	Prediction probabilities of the positive class >0.502 will be predicted as the positive class (true). This can significantly impact metric scores.
# (_dystack pid=14208) 	You can update this value via `predictor.set_decision_threshold`.
# (_dystack pid=14208) 	You can calculate an optimal decision threshold on the validation data via `predictor.calibrate_decision_threshold()`.
# (_dystack pid=14208) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("D:\projects\python\Genome-Transition-Auto-MLl\models\ei\combined\ds_sub_fit\sub_fit_ho")
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# (_dystack pid=14208) If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
# (_dystack pid=14208)   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# (_dystack pid=14208) D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# (_dystack pid=14208) If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
# (_dystack pid=14208)   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# (_dystack pid=14208) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                            model  score_holdout  score_val eval_metric  pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0    NeuralNetFastAI_BAG_L2_FULL       0.972525   0.972518          f1        3.229756            NaN  905.557942                 0.159154                     NaN          53.996839            2       True         20
# 1     ExtraTreesGini_BAG_L2_FULL       0.972362   0.972582          f1        3.209129            NaN  854.268252                 0.138527                1.725116           2.707150            2       True         18
# 2           CatBoost_BAG_L2_FULL       0.972166   0.971815          f1        3.091247            NaN  919.904276                 0.020645                     NaN          68.343173            2       True         17
# 3       WeightedEnsemble_L3_FULL       0.972166   0.972695          f1        3.272931            NaN  864.904662                 0.015032                     NaN           9.616641            3       True         24
# 4     ExtraTreesEntr_BAG_L2_FULL       0.971797   0.971995          f1        3.216191            NaN  853.862036                 0.145589                1.706968           2.300934            2       True         19
# 5            XGBoost_BAG_L2_FULL       0.971751   0.971565          f1        3.130604            NaN  852.179468                 0.060002                     NaN           0.618366            2       True         21
# 6   RandomForestGini_BAG_L2_FULL       0.971578   0.972525          f1        3.218326            NaN  857.225250                 0.147724                1.690533           5.664147            2       True         15
# 7         LightGBMXT_BAG_L2_FULL       0.971383   0.970391          f1        3.102315            NaN  852.296472                 0.031713                     NaN           0.735370            2       True         13
# 8      LightGBMLarge_BAG_L2_FULL       0.971359   0.972662          f1        3.119372            NaN  852.580871                 0.048770                     NaN           1.019769            2       True         23
# 9   RandomForestEntr_BAG_L2_FULL       0.971175   0.972124          f1        3.197128            NaN  856.801207                 0.126526                1.640430           5.240104            2       True         16
# ...
# D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# No improvement since epoch 0: early stopping
# D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 	55.54s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: XGBoost_BAG_L1_FULL ...
# 	4.3s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetTorch_BAG_L1_FULL ...
# 	349.51s	 = Training   runtime
# Fitting 1 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMLarge_BAG_L1_FULL ...
# 	11.96s	 = Training   runtime
# Fitting model: RandomForestEntr_BAG_L2_FULL | Skipping fit via cloning parent ...
# 	5.83s	 = Training   runtime
# 	1.74s	 = Validation runtime
# Updated best model to "RandomForestEntr_BAG_L2_FULL" (Previously "WeightedEnsemble_L3"). AutoGluon will default to using "RandomForestEntr_BAG_L2_FULL" for predict() and predict_proba().
# Refit complete, total runtime = 1252.53s ... Best model: "RandomForestEntr_BAG_L2_FULL"
# Enabling decision threshold calibration (calibrate_decision_threshold='auto', metric is valid, problem_type is 'binary')
# Calibrating decision threshold to optimize metric f1 | Checking 51 thresholds...
# Calibrating decision threshold via fine-grained search | Checking 38 thresholds...
# 	Base Threshold: 0.500	| val: 0.9751
# 	Best Threshold: 0.559	| val: 0.9752
# Updating predictor.decision_threshold from 0.5 -> 0.559
# 	This will impact how prediction probabilities are converted to predictions in binary classification.
# 	Prediction probabilities of the positive class >0.559 will be predicted as the positive class (true). This can significantly impact metric scores.
# 	You can update this value via `predictor.set_decision_threshold`.
# 	You can calculate an optimal decision threshold on the validation data via `predictor.calibrate_decision_threshold()`.
# Deleting model LightGBMXT_BAG_L1. All files under D:\projects\python\Genome-Transition-Auto-MLl\models\ei\combined\models\LightGBMXT_BAG_L1 will be removed.
# Deleting model LightGBM_BAG_L1. All files under D:\projects\python\Genome-Transition-Auto-MLl\models\ei\combined\models\LightGBM_BAG_L1 will be removed.
# Deleting model RandomForestGini_BAG_L1. All files under D:\projects\python\Genome-Transition-Auto-MLl\models\ei\combined\models\RandomForestGini_BAG_L1 will be removed.
# Deleting model RandomForestEntr_BAG_L1. All files under D:\projects\python\Genome-Transition-Auto-MLl\models\ei\combined\models\RandomForestEntr_BAG_L1 will be removed.
# Deleting model CatBoost_BAG_L1. All files under D:\projects\python\Genome-Transition-Auto-MLl\models\ei\combined\models\CatBoost_BAG_L1 will be removed.
# Deleting model ExtraTreesGini_BAG_L1. All files under D:\projects\python\Genome-Transition-Auto-MLl\models\ei\combined\models\ExtraTreesGini_BAG_L1 will be removed.
# Deleting model ExtraTreesEntr_BAG_L1. All files under D:\projects\python\Genome-Transition-Auto-MLl\models\ei\combined\models\ExtraTreesEntr_BAG_L1 will be removed.
# Deleting model NeuralNetFastAI_BAG_L1. All files under D:\projects\python\Genome-Transition-Auto-MLl\models\ei\combined\models\NeuralNetFastAI_BAG_L1 will be removed.
# Deleting model XGBoost_BAG_L1. All files under D:\projects\python\Genome-Transition-Auto-MLl\models\ei\combined\models\XGBoost_BAG_L1 will be removed.
# Deleting model NeuralNetTorch_BAG_L1. All files under D:\projects\python\Genome-Transition-Auto-MLl\models\ei\combined\models\NeuralNetTorch_BAG_L1 will be removed.
# Deleting model LightGBMLarge_BAG_L1. All files under D:\projects\python\Genome-Transition-Auto-MLl\models\ei\combined\models\LightGBMLarge_BAG_L1 will be removed.
# Deleting model WeightedEnsemble_L2. All files under D:\projects\python\Genome-Transition-Auto-MLl\models\ei\combined\models\WeightedEnsemble_L2 will be removed.
# Deleting model LightGBMXT_BAG_L2. All files under D:\projects\python\Genome-Transition-Auto-MLl\models\ei\combined\models\LightGBMXT_BAG_L2 will be removed.
# Deleting model LightGBM_BAG_L2. All files under D:\projects\python\Genome-Transition-Auto-MLl\models\ei\combined\models\LightGBM_BAG_L2 will be removed.
# Deleting model RandomForestGini_BAG_L2. All files under D:\projects\python\Genome-Transition-Auto-MLl\models\ei\combined\models\RandomForestGini_BAG_L2 will be removed.
# Deleting model RandomForestEntr_BAG_L2. All files under D:\projects\python\Genome-Transition-Auto-MLl\models\ei\combined\models\RandomForestEntr_BAG_L2 will be removed.
# Deleting model CatBoost_BAG_L2. All files under D:\projects\python\Genome-Transition-Auto-MLl\models\ei\combined\models\CatBoost_BAG_L2 will be removed.
# Deleting model ExtraTreesGini_BAG_L2. All files under D:\projects\python\Genome-Transition-Auto-MLl\models\ei\combined\models\ExtraTreesGini_BAG_L2 will be removed.
# Deleting model ExtraTreesEntr_BAG_L2. All files under D:\projects\python\Genome-Transition-Auto-MLl\models\ei\combined\models\ExtraTreesEntr_BAG_L2 will be removed.
# Deleting model NeuralNetFastAI_BAG_L2. All files under D:\projects\python\Genome-Transition-Auto-MLl\models\ei\combined\models\NeuralNetFastAI_BAG_L2 will be removed.
# Deleting model XGBoost_BAG_L2. All files under D:\projects\python\Genome-Transition-Auto-MLl\models\ei\combined\models\XGBoost_BAG_L2 will be removed.
# Deleting model NeuralNetTorch_BAG_L2. All files under D:\projects\python\Genome-Transition-Auto-MLl\models\ei\combined\models\NeuralNetTorch_BAG_L2 will be removed.
# Deleting model LightGBMLarge_BAG_L2. All files under D:\projects\python\Genome-Transition-Auto-MLl\models\ei\combined\models\LightGBMLarge_BAG_L2 will be removed.
# Deleting model WeightedEnsemble_L3. All files under D:\projects\python\Genome-Transition-Auto-MLl\models\ei\combined\models\WeightedEnsemble_L3 will be removed.
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("D:\projects\python\Genome-Transition-Auto-MLl\models\ei\combined")
# D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\fastai\learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# Results for combined:
#                            model  score_test score_val eval_metric  \
# 0   RandomForestEntr_BAG_L2_FULL    0.973865      None          f1
# 1      LightGBMLarge_BAG_L1_FULL    0.972153      None          f1
# 2            XGBoost_BAG_L1_FULL    0.971640      None          f1
# 3         LightGBMXT_BAG_L1_FULL    0.970114      None          f1
# 4           LightGBM_BAG_L1_FULL    0.969751      None          f1
# 5     NeuralNetTorch_BAG_L1_FULL    0.968885      None          f1
# 6   RandomForestGini_BAG_L1_FULL    0.964867      None          f1
# 7           CatBoost_BAG_L1_FULL    0.964247      None          f1
# 8   RandomForestEntr_BAG_L1_FULL    0.962901      None          f1
# 9     ExtraTreesGini_BAG_L1_FULL    0.956632      None          f1
# 10    ExtraTreesEntr_BAG_L1_FULL    0.954728      None          f1
# 11   NeuralNetFastAI_BAG_L1_FULL    0.915713      None          f1
#
#     pred_time_test  pred_time_val     fit_time  pred_time_test_marginal  \
# 0         9.866940            NaN  1265.118521                 0.185287
# 1         2.829647            NaN    11.962454                 2.829647
# 2         0.414227            NaN     4.297555                 0.414227
# 3         3.666034            NaN    12.339880                 3.666034
# 4         1.176956            NaN     7.021670                 1.176956
# 5         0.176993            NaN   349.512278                 0.176993
# 6         0.234456       1.786993     2.886807                 0.234456
# 7         0.117523            NaN   808.883289                 0.117523
# 8         0.202614       1.770829     2.495834                 0.202614
# 9         0.202652       1.864680     2.254139                 0.202652
# 10        0.202750       1.848873     2.099149                 0.202750
# 11        0.457801            NaN    55.538630                 0.457801
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 1.737098           5.826838            2       True
# 1                      NaN          11.962454            1       True
# 2                      NaN           4.297555            1       True
# 3                      NaN          12.339880            1       True
# 4                      NaN           7.021670            1       True
# 5                      NaN         349.512278            1       True
# 6                 1.786993           2.886807            1       True
# 7                      NaN         808.883289            1       True
# 8                 1.770829           2.495834            1       True
# 9                 1.864680           2.254139            1       True
# 10                1.848873           2.099149            1       True
# 11                     NaN          55.538630            1       True
#
#     fit_order
# 0          12
# 1          11
# 2           9
# 3           1
# 4           2
# 5          10
# 6           3
# 7           5
# 8           4
# 9           6
# 10          7
# 11          8

# %%
true_file = "../data/ie/data_ie.csv"
ie_true_data = pd.read_csv(true_file)

# List of counter example files for the EI zone
counter_files = {
    "combined": pd.concat(
        [
            pd.read_csv("../data/ie/data_ie_random.csv"),
            pd.read_csv("../data/ie/data_ez_counter_example.csv"),
            pd.read_csv("../data/ie/data_ei_true_counter_example.csv"),
            pd.read_csv("../data/ie/data_ei_counter_example.csv"),
            pd.read_csv("../data/ie/data_ze_counter_example.csv"),
            pd.read_csv("../data/ie/data_test_false.csv"),
         ]
    )
}

# For EI zone, our CSV files have columns B1 to B105.
combined_data = prepare_data(ie_true_data, counter_files, max_index=105)

# Dictionary to store the combined DataFrames and later model results
generateModels(combined_data, 'ie', 105, time_limit=21600)

# %%
true_file = "../data/ez/data_ez.csv"
ez_true_data = pd.read_csv(true_file)

# List of counter example files for the EI zone
counter_files = {
    "combined": pd.concat(
        [
            pd.read_csv("../data/ez/data_ez_random.csv"),
            pd.read_csv("../data/ez/data_ei_counter_example.csv"),
            pd.read_csv("../data/ez/data_ie_counter_example.csv"),
            pd.read_csv("../data/ez/data_ze_counter_example.csv"),
         ]
    )
}

# For EI zone, our CSV files have columns B1 to B550.
combined_data = prepare_data(ez_true_data, counter_files, max_index=550)

# Dictionary to store the combined DataFrames and later model results
generateModels(combined_data, 'ez', 550, time_limit=13000)
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_16400\3073969184.py:2: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   ez_true_data = pd.read_csv(true_file)
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_16400\3073969184.py:8: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv("../data/ez/data_ez_random.csv"),
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_16400\3073969184.py:9: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv("../data/ez/data_ei_counter_example.csv"),
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_16400\3073969184.py:10: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv("../data/ez/data_ie_counter_example.csv"),
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_16400\3073969184.py:11: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv("../data/ez/data_ze_counter_example.csv"),
# Warning: path already exists! This predictor may overwrite an existing predictor! path="../models/ez/combined"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.2
# Python Version:     3.9.13
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.26100
# CPU Count:          16
# Memory Avail:       1.42 GB / 15.35 GB (9.3%)
# Disk Space Avail:   46.96 GB / 100.00 GB (47.0%)
# ===================================================
# Presets specified: ['good_quality', 'optimize_for_deployment']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Note: `save_bag_folds=False`! This will greatly reduce peak disk usage during fit (by ~8x), but runs the risk of an out-of-memory error during model refit if memory is small relative to the data size.
# 	You can avoid this risk by setting `save_bag_folds=True`.
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 3250s of the 13000s of remaining time (25%).
# 2025-04-04 12:10:24,213	INFO util.py:154 -- Missing packages: ['ipywidgets']. Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-04-04 12:10:31,825	INFO worker.py:1810 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# 		Context path: "D:\projects\python\Genome-Transition-Auto-MLl\models\ez\combined\ds_sub_fit\sub_fit_ho"
# (_dystack pid=5828) Running DyStack sub-fit ...
# (_dystack pid=5828) Beginning AutoGluon training ... Time limit = 3238s
# (_dystack pid=5828) AutoGluon will save models to "D:\projects\python\Genome-Transition-Auto-MLl\models\ez\combined\ds_sub_fit\sub_fit_ho"
# (_dystack pid=5828) Train Data Rows:    176135
# (_dystack pid=5828) Train Data Columns: 550
# (_dystack pid=5828) Label Column:       label
# (_dystack pid=5828) Problem Type:       binary
# (_dystack pid=5828) Preprocessing data ...
# (_dystack pid=5828) Selected class <--> label mapping:  class 1 = true, class 0 = false
# (_dystack pid=5828) 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive (true) vs negative (false) class.
# (_dystack pid=5828) 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# (_dystack pid=5828) Using Feature Generators to preprocess the data ...
# (_dystack pid=5828) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=5828) 	Available Memory:                    8722.52 MB
# (_dystack pid=5828) 	Train Data (Original)  Memory Usage: 5358.42 MB (61.4% of available memory)
# (_dystack pid=5828) 	Warning: Data size prior to feature transformation consumes 61.4% of available memory. Consider increasing memory or subsampling the data to avoid instability.
# (_dystack pid=5828) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=5828) 	Stage 1 Generators:
# (_dystack pid=5828) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=5828) 	Stage 2 Generators:
# (_dystack pid=5828) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=5828) 	Stage 3 Generators:
# (_dystack pid=5828) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=5828) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=5828) 	Stage 4 Generators:
# (_dystack pid=5828) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=5828) 	Stage 5 Generators:
# (_dystack pid=5828) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=5828) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=5828) 		('object', []) : 550 | ['B1', 'B2', 'B3', 'B4', 'B5', ...]
# (_dystack pid=5828) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=5828) 		('category', []) : 550 | ['B1', 'B2', 'B3', 'B4', 'B5', ...]
# (_dystack pid=5828) 	56.7s = Fit runtime
# (_dystack pid=5828) 	550 features in original data used to generate 550 features in processed data.
# (_dystack pid=5828) 	Train Data (Processed) Memory Usage: 92.66 MB (1.0% of available memory)
# (_dystack pid=5828) Data preprocessing and feature engineering runtime = 60.83s ...
# (_dystack pid=5828) AutoGluon will gauge predictive performance using evaluation metric: 'f1'
# (_dystack pid=5828) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=5828) User-specified model hyperparameters to be fit:
# (_dystack pid=5828) {
# (_dystack pid=5828) 	'NN_TORCH': [{}],
# (_dystack pid=5828) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# (_dystack pid=5828) 	'CAT': [{}],
# (_dystack pid=5828) 	'XGB': [{}],
# (_dystack pid=5828) 	'FASTAI': [{}],
# (_dystack pid=5828) 	'RF': [{'criterion': 'gini', 'max_depth': 15, 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'max_depth': 15, 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'max_depth': 15, 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=5828) 	'XT': [{'criterion': 'gini', 'max_depth': 15, 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'max_depth': 15, 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'max_depth': 15, 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=5828) }
# (_dystack pid=5828) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=5828) Fitting 11 L1 models, fit_strategy="sequential" ...
# (_dystack pid=5828) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 2117.34s of the 3176.80s of remaining time.
# (_dystack pid=5828) 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 15.47% memory usage per fold, 61.87%/80.00% total).
# (_dystack pid=5828) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=4, gpus=0, memory=15.47%)
# (autoscaler +1m58s) Tip: use `ray status` to view detailed cluster status. To disable these messages, set RAY_SCHEDULER_EVENTS=0.
# (autoscaler +1m58s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +2m33s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +3m9s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +3m44s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +4m19s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +4m54s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +5m29s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +6m4s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +6m39s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +7m14s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +7m49s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +8m24s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +8m59s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +9m34s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +10m9s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +10m44s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +11m19s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +11m54s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +12m30s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +13m5s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +13m40s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +14m15s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +14m50s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +15m25s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +16m0s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +16m35s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +17m10s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +17m45s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +18m20s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +18m55s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +19m30s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +20m5s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +20m40s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +21m15s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +21m51s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +22m26s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +23m1s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +23m36s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +24m11s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +24m46s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +25m21s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +25m56s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +26m31s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +27m6s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +27m41s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +28m16s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +28m51s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +29m26s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +30m1s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +30m37s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +31m12s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +31m47s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +32m22s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +32m57s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +33m32s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +34m7s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +34m42s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +35m17s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +35m52s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +36m27s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +37m2s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +37m37s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +38m12s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +38m47s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +39m22s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +39m58s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +40m33s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +41m8s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +41m43s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +42m18s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +42m53s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +43m28s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +44m3s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +44m38s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +45m13s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +45m48s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +46m23s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +46m58s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +47m33s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +48m8s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +48m43s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +49m19s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +49m54s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +50m29s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +51m4s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +51m39s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +52m14s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +52m49s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +53m24s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +53m59s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +54m34s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +55m9s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +55m44s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +56m19s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +56m54s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +57m29s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +58m4s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +58m40s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +59m15s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +59m50s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h25s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h1m0s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h1m35s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h2m10s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h2m45s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h3m20s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h3m55s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h4m30s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h5m5s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h5m40s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h6m15s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h6m50s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h7m25s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h8m0s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h8m35s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h9m10s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h9m46s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h10m21s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h10m56s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h11m31s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h12m6s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h12m41s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h13m16s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h13m51s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h14m26s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h15m1s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h15m36s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h16m11s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h16m46s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h17m21s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h17m56s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h18m31s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h19m7s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h19m42s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h20m17s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h20m52s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h21m27s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h22m2s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h22m37s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h23m12s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h23m47s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h24m22s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h24m57s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h25m32s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h26m7s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h26m42s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h27m17s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h27m52s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h28m27s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h29m3s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h29m38s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h30m13s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h30m48s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h31m23s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h31m58s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h32m33s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h33m8s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h33m43s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h34m18s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +1h34m53s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# ...
# (autoscaler +5h40m53s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +5h41m28s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +5h42m3s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +5h42m38s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +5h43m13s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +5h43m48s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +5h44m23s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +5h44m59s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +5h45m34s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +5h46m9s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +5h46m44s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +5h47m19s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +5h47m54s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +5h48m29s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +5h49m4s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +5h49m39s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +5h50m14s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +5h50m49s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +5h51m24s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +5h51m59s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +5h52m34s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +5h53m9s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +5h53m45s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +5h54m20s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +5h54m55s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +5h55m30s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +5h56m5s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +5h56m40s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +5h57m15s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +5h57m50s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +5h58m25s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +5h59m0s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +5h59m35s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +6h10s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +6h45s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +6h1m20s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +6h1m55s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# (autoscaler +6h2m30s) Warning: The following resource request cannot be scheduled right now: {'CPU': 4.0}. This is likely due to all cluster resources being claimed by actors. Consider creating fewer actors or adding more nodes to this Ray cluster.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 20
#      17 combined_data = prepare_data(ez_true_data, counter_files, max_index=550)
#      19 # Dictionary to store the combined DataFrames and later model results
# ---> 20 generateModels(combined_data, 'ez', 550, time_limit=13000)
#
# Cell In[5], line 23, in generateModels(combined_data, prefix, max_index, time_limit)
#      20 os.makedirs(output_folder, exist_ok=True)
#      22 # Train the model using AutoGluon.
# ---> 23 predictor = TabularPredictor(label="label", path=output_folder, eval_metric='f1').fit(train_data, presets=presets, time_limit=time_limit)
#      25 # Evaluate the model on the test data.
#      26 leaderboard = predictor.leaderboard(test_data, silent=True)
#
# File D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\autogluon\core\utils\decorators.py:31, in unpack.<locals>._unpack_inner.<locals>._call(*args, **kwargs)
#      28 @functools.wraps(f)
#      29 def _call(*args, **kwargs):
#      30     gargs, gkwargs = g(*other_args, *args, **kwargs)
# ---> 31     return f(*gargs, **gkwargs)
#
# File D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\autogluon\tabular\predictor\predictor.py:1280, in TabularPredictor.fit(self, train_data, tuning_data, time_limit, presets, hyperparameters, feature_metadata, infer_limit, infer_limit_batch_size, fit_weighted_ensemble, fit_full_last_level_weighted_ensemble, full_weighted_ensemble_additionally, dynamic_stacking, calibrate_decision_threshold, num_cpus, num_gpus, fit_strategy, memory_limit, callbacks, **kwargs)
#    1274 if dynamic_stacking:
#    1275     logger.log(
#    1276         20,
#    1277         f"DyStack is enabled (dynamic_stacking={dynamic_stacking}). "
#    1278         "AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.",
#    1279     )
# -> 1280     num_stack_levels, time_limit = self._dynamic_stacking(**ds_args, ag_fit_kwargs=ag_fit_kwargs, ag_post_fit_kwargs=ag_post_fit_kwargs)
#    1281     logger.info(
#    1282         f"Starting main fit with num_stack_levels={num_stack_levels}.\n"
#    1283         f"\tFor future fit calls on this dataset, you can skip DyStack to save time: "
#    1284         f"`predictor.fit(..., dynamic_stacking=False, num_stack_levels={num_stack_levels})`"
#    1285     )
#    1287     if (time_limit is not None) and (time_limit <= 0):
#
# File D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\autogluon\tabular\predictor\predictor.py:1380, in TabularPredictor._dynamic_stacking(self, ag_fit_kwargs, ag_post_fit_kwargs, validation_procedure, detection_time_frac, holdout_frac, n_folds, n_repeats, memory_safe_fits, clean_up_fits, enable_ray_logging, enable_callbacks, holdout_data)
#    1377         _, holdout_data, _, _ = self._validate_fit_data(train_data=X, tuning_data=holdout_data)
#    1378         ds_fit_kwargs["ds_fit_context"] = os.path.join(ds_fit_context, "sub_fit_custom_ho")
# -> 1380     stacked_overfitting = self._sub_fit_memory_save_wrapper(
#    1381         train_data=X,
#    1382         time_limit=time_limit,
#    1383         time_start=time_start,
#    1384         ds_fit_kwargs=ds_fit_kwargs,
#    1385         ag_fit_kwargs=inner_ag_fit_kwargs,
#    1386         ag_post_fit_kwargs=inner_ag_post_fit_kwargs,
#    1387         holdout_data=holdout_data,
#    1388     )
#    1389 else:
#    1390     # Holdout is false, use (repeated) cross-validation
#    1391     is_stratified = self.problem_type in [REGRESSION, QUANTILE, SOFTCLASS]
#
# File D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\autogluon\tabular\predictor\predictor.py:1563, in TabularPredictor._sub_fit_memory_save_wrapper(self, train_data, time_limit, time_start, ds_fit_kwargs, ag_fit_kwargs, ag_post_fit_kwargs, holdout_data)
#    1549 # FIXME: For some reason ray does not treat `num_cpus` and `num_gpus` the same.
#    1550 #  For `num_gpus`, the process will reserve the capacity and is unable to share it to child ray processes, causing a deadlock.
#    1551 #  For `num_cpus`, the value is completely ignored by children, and they can even use more num_cpus than the parent.
#    1552 #  Because of this, num_gpus is set to 0 here to avoid a deadlock, but num_cpus does not need to be changed.
#    1553 #  For more info, refer to Ray documentation: https://docs.ray.io/en/latest/ray-core/tasks/nested-tasks.html#yielding-resources-while-blocked
#    1554 ref = sub_fit_caller.options(num_cpus=num_cpus, num_gpus=0).remote(
#    1555     predictor=predictor_ref,
#    1556     train_data=train_data_ref,
#    (...)
#    1561     holdout_data=holdout_data_ref,
#    1562 )
# -> 1563 finished, unfinished = _ds_ray.wait([ref], num_returns=1)
#    1564 stacked_overfitting, ho_leaderboard, exception = _ds_ray.get(finished[0])
#    1566 # TODO: This is present to ensure worker logs are properly logged and don't get skipped / printed out of order.
#    1567 #  Ideally find a faster way to do this that doesn't introduce a 100 ms overhead.
#
# File D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\ray\_private\auto_init_hook.py:21, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      18 @wraps(fn)
#      19 def auto_init_wrapper(*args, **kwargs):
#      20     auto_init_ray()
# ---> 21     return fn(*args, **kwargs)
#
# File D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\ray\_private\client_mode_hook.py:103, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     101     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     102         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 103 return func(*args, **kwargs)
#
# File D:\projects\python\Genome-Transition-Auto-MLl\.venv\lib\site-packages\ray\_private\worker.py:2984, in wait(ray_waitables, num_returns, timeout, fetch_local)
#    2982 timeout = timeout if timeout is not None else 10**6
#    2983 timeout_milliseconds = int(timeout * 1000)
# -> 2984 ready_ids, remaining_ids = worker.core_worker.wait(
#    2985     ray_waitables,
#    2986     num_returns,
#    2987     timeout_milliseconds,
#    2988     worker.current_task_id,
#    2989     fetch_local,
#    2990 )
#    2991 return ready_ids, remaining_ids
#
# File python\ray\_raylet.pyx:3816, in ray._raylet.CoreWorker.wait()
#
# File python\ray\includes/common.pxi:79, in ray._raylet.check_status()
#
# KeyboardInterrupt:

# %%
true_file = "../data/ze/data_ze.csv"
ze_true_data = pd.read_csv(true_file)

# List of counter example files for the EI zone
counter_files = {
    "combined": pd.concat(
        [
            pd.read_csv("../data/ze/data_ze_random.csv"),
            pd.read_csv("../data/ze/data_ez_counter_example.csv"),
            pd.read_csv("../data/ze/data_ie_counter_example.csv"),
            pd.read_csv("../data/ze/data_ei_counter_example.csv"),
         ]
    )
}

# For EZ zone, our CSV files have columns B1 to B550.
combined_data = prepare_data(ze_true_data, counter_files, max_index=550)

# Dictionary to store the combined DataFrames and later model results
generateModels(combined_data, 'ze', 550, time_limit=13000)
